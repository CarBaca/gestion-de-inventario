# %% [markdown]
# Cargar las librerias

# %%
### Protecto Final
#Carga de librerias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# Leer los archivos

# %%
PurchasesFinal = pd.read_csv("PurchasesFINAL12312016.csv",sep=',')
SalesFinal = pd.read_csv("SalesFINAL12312016.csv",sep=',')
EndInvFINAL = pd.read_csv("EndInvFINAL12312016.csv",sep=',')
BegInvFINAL = pd.read_csv("BegInvFINAL12312016.csv",sep=',')
PurchasePricesDec = pd.read_csv("2017PurchasePricesDec.csv",sep=',')
InvoicePurchases = pd.read_csv("InvoicePurchases12312016.csv",sep=',')

# %% [markdown]
# Comprobar nulos

# %%
#comprobando los datos nulos, mayores a 4'000'000
#data_latinoamerica.isnull().sum()[data_latinoamerica.isnull().sum()>4000000]
PurchasesFinal.isnull()
# Out:
#          InventoryId  Store  Brand  Description   Size  VendorNumber  \
# 0              False  False  False        False  False         False
# 1              False  False  False        False  False         False
# 2              False  False  False        False  False         False
# 3              False  False  False        False  False         False
# 4              False  False  False        False  False         False
# ...              ...    ...    ...          ...    ...           ...
# 2372469        False  False  False        False  False         False
# 2372470        False  False  False        False  False         False
# 2372471        False  False  False        False  False         False
# 2372472        False  False  False        False  False         False
# 2372473        False  False  False        False  False         False
#
#          VendorName  PONumber  PODate  ReceivingDate  InvoiceDate  PayDate  \
# ...

# %%
SalesFinal.isnull()
# Out:
#          InventoryId  Store  Brand  Description   Size  SalesQuantity  \
# 0              False  False  False        False  False          False
# 1              False  False  False        False  False          False
# 2              False  False  False        False  False          False
# 3              False  False  False        False  False          False
# 4              False  False  False        False  False          False
# ...              ...    ...    ...          ...    ...            ...
# 1048570        False  False  False        False  False          False
# 1048571        False  False  False        False  False          False
# 1048572        False  False  False        False  False          False
# 1048573        False  False  False        False  False          False
# 1048574        False  False  False        False  False          False
#
#          SalesDollars  SalesPrice  SalesDate  Volume  Classification  \
# ...

# %%
PurchasesFinalnulos = PurchasesFinal.isnull().sum()[PurchasesFinal.isnull().sum()>0]
print(PurchasesFinalnulos)
# Out:
# Size    3
# dtype: int64

# %%
SalesFinalnulos = SalesFinal.isnull().sum()[SalesFinal.isnull().sum()>0]
print(SalesFinalnulos)
# Out:
# Series([], dtype: int64)

# %%
#Verificar si hay filas con valores nulos
filas_nulas = EndInvFINAL.isnull().any(axis=1)

#Mostrar filas con valores nulos
filas_con_nulos = EndInvFINAL[filas_nulas]

#Imprimir las filas con valores nulos
if not filas_con_nulos.empty:
    print("Filas con valores nulos encontradas:")
    print(filas_con_nulos)
else:
    print("No se encontraron filas con valores nulos.")
# Out:
# Filas con valores nulos encontradas:
#        InventoryId  Store City  Brand                   Description   Size  \
# 113895      46__58     46  NaN     58   Gekkeikan Black & Gold Sake  750mL
# 113896      46__62     46  NaN     62      Herradura Silver Tequila  750mL
# 113897      46__63     46  NaN     63    Herradura Reposado Tequila  750mL
# 113898      46__77     46  NaN     77   Three Olives Espresso Vodka  750mL
# 113899     46__106     46  NaN    106      Mr Boston Peach Schnapps  Liter
# ...            ...    ...  ...    ...                           ...    ...
# 115174   46__46447     46  NaN  46447         Gascon Malbec Mendoza  750mL
# 115175   46__46458     46  NaN  46458      Layer Cake Barosa Shiraz  750mL
# 115176   46__46476     46  NaN  46476          Tilia Malbec Mendoza  750mL
# 115177   46__46764     46  NaN  46764  Clayhouse Adobe Red Paso Rbl  750mL
# 115178   46__46830     46  NaN  46830         Pacific Rim Sweet Rsl  750mL
#
# ...

# %%
#Verificar si hay duplicados en todo el DataFrame
duplicados = PurchasesFinal.duplicated()

#Mostrar filas duplicadas
duplicados_filas = PurchasesFinal[duplicados]

#Imprimir las filas duplicadas
if not duplicados_filas.empty:
    print("Filas duplicadas encontradas:")
    print(duplicados_filas)
else:
    print("No se encontraron filas duplicadas.")
# Out:
# No se encontraron filas duplicadas.

# %%
#Verificar si hay duplicados en todo el DataFrame
duplicados = SalesFinal.duplicated()

#Mostrar filas duplicadas
duplicados_filas = SalesFinal[duplicados]

#Imprimir las filas duplicadas
if not duplicados_filas.empty:
    print("Filas duplicadas encontradas:")
    print(duplicados_filas)
else:
    print("No se encontraron filas duplicadas.")
# Out:
# No se encontraron filas duplicadas.

# %%
#Verificar si hay duplicados en todo el DataFrame
duplicados = EndInvFINAL.duplicated()

#Mostrar filas duplicadas
duplicados_filas = EndInvFINAL[duplicados]

#Imprimir las filas duplicadas
if not duplicados_filas.empty:
    print("Filas duplicadas encontradas:")
    print(duplicados_filas)
else:
    print("No se encontraron filas duplicadas.")
# Out:
# No se encontraron filas duplicadas.

# %% [markdown]
# Reemplazar nulos por ciudad

# %%
EndInvFINAL['City'].fillna('TYWARDREATH', inplace=True)
# Out:
# C:\Users\Win10\AppData\Local\Temp\ipykernel_12584\2512669720.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   EndInvFINAL['City'].fillna('TYWARDREATH', inplace=True)

# %%
#Verificar si hay filas con valores nulos
filas_nulas = EndInvFINAL.isnull().any(axis=1)

#Mostrar filas con valores nulos
filas_con_nulos = EndInvFINAL[filas_nulas]

#Imprimir las filas con valores nulos
if not filas_con_nulos.empty:
    print("Filas con valores nulos encontradas:")
    print(filas_con_nulos)
else:
    print("No se encontraron filas con valores nulos.")
# Out:
# No se encontraron filas con valores nulos.

# %%
#Verificar si hay filas con valores nulos
filas_nulas = BegInvFINAL.isnull().any(axis=1)

#Mostrar filas con valores nulos
filas_con_nulos = BegInvFINAL[filas_nulas]

#Imprimir las filas con valores nulos
if not filas_con_nulos.empty:
    print("Filas con valores nulos encontradas:")
    print(filas_con_nulos)
else:
    print("No se encontraron filas con valores nulos.")
# Out:
# No se encontraron filas con valores nulos.

# %%
#Verificar si hay filas con valores nulos
filas_nulas = PurchasePricesDec.isnull().any(axis=1)

#Mostrar filas con valores nulos
filas_con_nulos = PurchasePricesDec[filas_nulas]

#Imprimir las filas con valores nulos
if not filas_con_nulos.empty:
    print("Filas con valores nulos encontradas:")
    print(filas_con_nulos)
else:
    print("No se encontraron filas con valores nulos.")
# Out:
# Filas con valores nulos encontradas:
#       Brand Description  Price Size Volume  Classification  PurchasePrice  \
# 7915   4202         NaN    0.0  NaN    NaN               1          11.19
#
#       VendorNumber                   VendorName
# 7915           480  BACARDI USA INC

# %%
#Verificar si hay filas con valores nulos
filas_nulas = InvoicePurchases.isnull().any(axis=1)

#Mostrar filas con valores nulos
filas_con_nulos = InvoicePurchases[filas_nulas]

#Imprimir las filas con valores nulos
if not filas_con_nulos.empty:
    print("Filas con valores nulos encontradas:")
    print(filas_con_nulos)
else:
    print("No se encontraron filas con valores nulos.")
# Out:
# Filas con valores nulos encontradas:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0              105  ALTAMAR BRANDS LLC           2016-01-04      8124
# 1             4466  AMERICAN VINTAGE BEVERAGE    2016-01-07      8137
# 2              388  ATLANTIC IMPORTING COMPANY   2016-01-09      8169
# 3              480  BACARDI USA INC              2016-01-12      8106
# 4              516  BANFI PRODUCTS CORP          2016-01-07      8170
# ...            ...                          ...         ...       ...
# 5538          9622  WEIN BAUER INC               2017-01-06     13626
# 5539          9625  WESTERN SPIRITS BEVERAGE CO  2017-01-10     13661
# 5540          3664  WILLIAM GRANT & SONS INC     2017-01-02     13643
# 5541          9815  WINE GROUP INC               2017-01-03     13602
# 5542         90058  ZORVINO VINEYARDS            2017-01-05     13574
#
#           PODate     PayDate  Quantity    Dollars  Freight Approval
# ...

# %% [markdown]
# Eliminar Columna Approval

# %%
InvoicePurchases = InvoicePurchases.drop('Approval', axis=1)

# %% [markdown]
# Ya no hay nulos, continuamos vienod duplicados.

# %%
#Verificar si hay duplicados en todo el DataFrame
duplicados = BegInvFINAL.duplicated()

#Mostrar filas duplicadas
duplicados_filas = BegInvFINAL[duplicados]

#Imprimir las filas duplicadas
if not duplicados_filas.empty:
    print("Filas duplicadas encontradas:")
    print(duplicados_filas)
else:
    print("No se encontraron filas duplicadas.")
# Out:
# No se encontraron filas duplicadas.

# %%
#Verificar si hay duplicados en todo el DataFrame
duplicados = PurchasePricesDec.duplicated()

#Mostrar filas duplicadas
duplicados_filas = PurchasePricesDec[duplicados]

#Imprimir las filas duplicadas
if not duplicados_filas.empty:
    print("Filas duplicadas encontradas:")
    print(duplicados_filas)
else:
    print("No se encontraron filas duplicadas.")
# Out:
# No se encontraron filas duplicadas.

# %%
#Verificar si hay duplicados en todo el DataFrame
duplicados = InvoicePurchases.duplicated()

#Mostrar filas duplicadas
duplicados_filas = InvoicePurchases[duplicados]

#Imprimir las filas duplicadas
if not duplicados_filas.empty:
    print("Filas duplicadas encontradas:")
    print(duplicados_filas)
else:
    print("No se encontraron filas duplicadas.")
# Out:
# No se encontraron filas duplicadas.
